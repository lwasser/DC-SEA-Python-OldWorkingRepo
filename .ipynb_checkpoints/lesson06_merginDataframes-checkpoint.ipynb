# %%
data = {'type': ['Decid', 'Decid', 'Decid', 'Decid', 'Decid', 'Conifer', 'Conifer', 'Decid'],
        'species': ['NL', 'DM', 'PF', 'PE', 'PP', 'PF', 'DS', 'Dogwood']}
treesDF = pd.DataFrame(data, columns=['type', 'species'])
treesDF
# Out:
#       type  species
# 0    Decid    Maple
# 1    Decid      Oak
# 2    Decid      Ash
# 3    Decid   Poplar
# 4    Decid    Olive
# 5  Conifer     Pine
# 6  Conifer      Fir
# 7    Decid  Dogwood

# %%
import pandas as pd
surveys_df = pd.read_csv('data/biology/surveys.csv', keep_default_na=False, na_values=[""])
species_df = pd.read_csv('data/biology/species.csv', keep_default_na=False, na_values=[""])

# %%
speciesSub = pd.read_csv('data/biology/speciesSubset.csv', keep_default_na=False, na_values=[""])
surveySub = surveys_df.head(10)

# %%
speciesSub=species_df.head()

# %%
species_df.columns
# Out:
# Index([u'species_id', u'genus', u'species', u'taxa'], dtype='object')

# %%
type(speciesSub)
# Out:
# pandas.core.frame.DataFrame

# %%
surveys_df
# Out:
#        record_id  month  day  year  plot species  sex  wgt
# 0              1      7   16  1977     2      NL    M  NaN
# 1              2      7   16  1977     3      NL    M  NaN
# 2              3      7   16  1977     2      DM    F  NaN
# 3              4      7   16  1977     7      DM    M  NaN
# 4              5      7   16  1977     3      DM    M  NaN
# 5              6      7   16  1977     1      PF    M  NaN
# 6              7      7   16  1977     2      PE    F  NaN
# 7              8      7   16  1977     1      DM    M  NaN
# 8              9      7   16  1977     1      DM    F  NaN
# 9             10      7   16  1977     6      PF    F  NaN
# 10            11      7   16  1977     5      DS    F  NaN
# 11            12      7   16  1977     7      DM    M  NaN
# 12            13      7   16  1977     3      DM    M  NaN
# 13            14      7   16  1977     8      DM  NaN  NaN
# 14            15      7   16  1977     6      DM    F  NaN
# ...

# %%
species_df
# Out:
#    species_id             genus          species                   taxa
# 0          AB        Amphispiza        bilineata                   Bird
# 1          AH  Ammospermophilus          harrisi    Rodent-not censused
# 2          AS        Ammodramus       savannarum                   Bird
# 3          BA           Baiomys          taylori                 Rodent
# 4          CB   Campylorhynchus  brunneicapillus                   Bird
# 5          CM       Calamospiza      melanocorys                   Bird
# 6          CQ        Callipepla         squamata                   Bird
# 7          CS          Crotalus       scutalatus                Reptile
# 8          CT     Cnemidophorus           tigris                Reptile
# 9          CU     Cnemidophorus        uniparens                Reptile
# 10         CV          Crotalus          viridis                Reptile
# 11         DM         Dipodomys         merriami                 Rodent
# ...

# %%
merged_inner = pd.merge(left=surveys_df, right=species_df, left_on='species', right_on='species_id')

# %%
merged_inner
# Out:
#        record_id  month  day  year  plot species_x  sex  wgt species_id  \
# 0              1      7   16  1977     2        NL    M  NaN         NL
# 1              2      7   16  1977     3        NL    M  NaN         NL
# 2             22      7   17  1977    15        NL    F  NaN         NL
# 3             38      7   17  1977    17        NL    M  NaN         NL
# 4             72      8   19  1977     2        NL    M  NaN         NL
# 5            106      8   20  1977    12        NL  NaN  NaN         NL
# 6            107      8   20  1977    18        NL  NaN  NaN         NL
# 7            121      8   21  1977    15        NL  NaN  NaN         NL
# 8            171      9   11  1977    12        NL  NaN  NaN         NL
# 9            194      9   12  1977    11        NL  NaN  NaN         NL
# 10           214      9   12  1977    17        NL  NaN  NaN         NL
# 11           224      9   13  1977     2        NL  NaN  NaN         NL
# ...

# %%
surveySub = surveys_df.head(10)

speciesSub = pd.read_csv('data/biology/speciesSubset.csv', keep_default_na=False, na_values=[""])

# %%
surveySub
# Out:
#    record_id  month  day  year  plot species sex  wgt
# 0          1      7   16  1977     2      NL   M  NaN
# 1          2      7   16  1977     3      NL   M  NaN
# 2          3      7   16  1977     2      DM   F  NaN
# 3          4      7   16  1977     7      DM   M  NaN
# 4          5      7   16  1977     3      DM   M  NaN
# 5          6      7   16  1977     1      PF   M  NaN
# 6          7      7   16  1977     2      PE   F  NaN
# 7          8      7   16  1977     1      DM   M  NaN
# 8          9      7   16  1977     1      DM   F  NaN
# 9         10      7   16  1977     6      PF   F  NaN

# %%
speciesSub
# Out:
#   species_id       genus   species    taxa
# 0         DM   Dipodomys  merriami  Rodent
# 1         NL     Neotoma  albigula  Rodent
# 2         PE  Peromyscus  eremicus  Rodent

# %%
surveySub.columns
# Out:
# Index([u'record_id', u'month', u'day', u'year', u'plot', u'species', u'sex', u'wgt'], dtype='object')

# %%
speciesSub.columns
# Out:
# Index([u'species_id', u'genus', u'species', u'taxa'], dtype='object')

# %%
merged_inner = pd.merge(left=surveySub, right=speciesSub, left_on='species', right_on='species_id')

# %%
merged_inner
# Out:
#    record_id  month  day  year  plot species_x sex  wgt species_id  \
# 0          1      7   16  1977     2        NL   M  NaN         NL
# 1          2      7   16  1977     3        NL   M  NaN         NL
# 2          3      7   16  1977     2        DM   F  NaN         DM
# 3          4      7   16  1977     7        DM   M  NaN         DM
# 4          5      7   16  1977     3        DM   M  NaN         DM
# 5          8      7   16  1977     1        DM   M  NaN         DM
# 6          9      7   16  1977     1        DM   F  NaN         DM
# 7          7      7   16  1977     2        PE   F  NaN         PE
#
#         genus species_y    taxa
# 0     Neotoma  albigula  Rodent
# 1     Neotoma  albigula  Rodent
# 2   Dipodomys  merriami  Rodent
# 3   Dipodomys  merriami  Rodent
# 4   Dipodomys  merriami  Rodent
# 5   Dipodomys  merriami  Rodent
# 6   Dipodomys  merriami  Rodent
# 7  Peromyscus  eremicus  Rodent

# %%
merged_inner.shape
# Out:
# (8, 12)

# %%
merged_left = pd.merge(left=surveySub, right=speciesSub, how='left', left_on='species', right_on='species_id')

merged_left
# Out:
#    record_id  month  day  year  plot species_x sex  wgt species_id  \
# 0          1      7   16  1977     2        NL   M  NaN         NL
# 1          2      7   16  1977     3        NL   M  NaN         NL
# 2          3      7   16  1977     2        DM   F  NaN         DM
# 3          4      7   16  1977     7        DM   M  NaN         DM
# 4          5      7   16  1977     3        DM   M  NaN         DM
# 5          8      7   16  1977     1        DM   M  NaN         DM
# 6          9      7   16  1977     1        DM   F  NaN         DM
# 7          6      7   16  1977     1        PF   M  NaN        NaN
# 8         10      7   16  1977     6        PF   F  NaN        NaN
# 9          7      7   16  1977     2        PE   F  NaN         PE
#
#         genus species_y    taxa
# 0     Neotoma  albigula  Rodent
# 1     Neotoma  albigula  Rodent
# 2   Dipodomys  merriami  Rodent
# 3   Dipodomys  merriami  Rodent
# 4   Dipodomys  merriami  Rodent
# ...

# %%
merged_left[ pd.isnull(merged_left.species_id) ]
# Out:
#    record_id  month  day  year  plot species_x sex  wgt species_id genus  \
# 7          6      7   16  1977     1        PF   M  NaN        NaN   NaN
# 8         10      7   16  1977     6        PF   F  NaN        NaN   NaN
#
#   species_y taxa
# 7       NaN  NaN
# 8       NaN  NaN

# %%
#read in first 10 lines of surveys table
surveySub = surveys_df.head(10)
surveySubLast10 = surveys_df[-10:-1]

# %%
surveySubLast10
# Out:
#        record_id  month  day  year  plot species  sex  wgt
# 35539      35540     12   31  2002    15      PB    F   23
# 35540      35541     12   31  2002    15      PB    F   31
# 35541      35542     12   31  2002    15      PB    F   29
# 35542      35543     12   31  2002    15      PB    F   34
# 35543      35544     12   31  2002    15      US  NaN  NaN
# 35544      35545     12   31  2002    15      AH  NaN  NaN
# 35545      35546     12   31  2002    15      AH  NaN  NaN
# 35546      35547     12   31  2002    10      RM    F   14
# 35547      35548     12   31  2002     7      DO    M   51

# %%
pd.concat([surveySub, surveySubLast10], axis=1)
# Out:
#        record_id  month  day  year  plot species  sex  wgt  record_id  month  \
# 0              1      7   16  1977     2      NL    M  NaN        NaN    NaN
# 1              2      7   16  1977     3      NL    M  NaN        NaN    NaN
# 2              3      7   16  1977     2      DM    F  NaN        NaN    NaN
# 3              4      7   16  1977     7      DM    M  NaN        NaN    NaN
# 4              5      7   16  1977     3      DM    M  NaN        NaN    NaN
# 5              6      7   16  1977     1      PF    M  NaN        NaN    NaN
# 6              7      7   16  1977     2      PE    F  NaN        NaN    NaN
# 7              8      7   16  1977     1      DM    M  NaN        NaN    NaN
# 8              9      7   16  1977     1      DM    F  NaN        NaN    NaN
# 9             10      7   16  1977     6      PF    F  NaN        NaN    NaN
# 35539        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN      35540     12
# ...

# %%
pd.concat([surveySub, surveySubLast10], axis=0)
# Out:
#        record_id  month  day  year  plot species  sex  wgt
# 0              1      7   16  1977     2      NL    M  NaN
# 1              2      7   16  1977     3      NL    M  NaN
# 2              3      7   16  1977     2      DM    F  NaN
# 3              4      7   16  1977     7      DM    M  NaN
# 4              5      7   16  1977     3      DM    M  NaN
# 5              6      7   16  1977     1      PF    M  NaN
# 6              7      7   16  1977     2      PE    F  NaN
# 7              8      7   16  1977     1      DM    M  NaN
# 8              9      7   16  1977     1      DM    F  NaN
# 9             10      7   16  1977     6      PF    F  NaN
# 35539      35540     12   31  2002    15      PB    F   23
# 35540      35541     12   31  2002    15      PB    F   31
# 35541      35542     12   31  2002    15      PB    F   29
# 35542      35543     12   31  2002    15      PB    F   34
# 35543      35544     12   31  2002    15      US  NaN  NaN
# ...

# %%
#read in first 10 lines of surveys table
surveySub = surveys_df.head(10)
#grab the last 10 rows (minus the last one)
surveySubLast10 = surveys_df[-10:-1]

# %%
surveySub
# Out:
#    record_id  month  day  year  plot species sex  wgt
# 0          1      7   16  1977     2      NL   M  NaN
# 1          2      7   16  1977     3      NL   M  NaN
# 2          3      7   16  1977     2      DM   F  NaN
# 3          4      7   16  1977     7      DM   M  NaN
# 4          5      7   16  1977     3      DM   M  NaN
# 5          6      7   16  1977     1      PF   M  NaN
# 6          7      7   16  1977     2      PE   F  NaN
# 7          8      7   16  1977     1      DM   M  NaN
# 8          9      7   16  1977     1      DM   F  NaN
# 9         10      7   16  1977     6      PF   F  NaN

# %%
#stack the DataFrames on top of each other
verticalStack=pd.concat([surveySub, surveySubLast10], axis=0)
#Place the DataFrames side by side
horizontalStack=pd.concat([surveySub, surveySubLast10], axis=1)

# %%
#need to test this to make sure it works
verticalStack.to_csv('out.csv')

# %%
surv2002=surveys_df[surveys_df.year==2002]
surv2001=surveys_df[surveys_df.year==2001]

# %%
surv2001
# Out:
#        record_id  month  day  year  plot species  sex  wgt
# 31710      31711      1   21  2001     1      PB    F   25
# 31711      31712      1   21  2001     1      DM    M   43
# 31712      31713      1   21  2001     1      PB    M   44
# 31713      31714      1   21  2001     1      DO    M   53
# 31714      31715      1   21  2001     2      OT    M   27
# 31715      31716      1   21  2001     2      RM    M   11
# 31716      31717      1   21  2001     2      NL    M  121
# 31717      31718      1   21  2001     2      DM    F   44
# 31718      31719      1   21  2001     2      PB    M   42
# 31719      31720      1   21  2001     2      PB    M   41
# 31720      31721      1   21  2001     2      NL    F  158
# 31721      31722      1   21  2001    12      DO    M   54
# 31722      31723      1   21  2001    12      DM    F   49
# 31723      31724      1   21  2001    12      OT    F   21
# 31724      31725      1   21  2001    12      DM    M   43
# ...

# %% [markdown]
# # Indexing and Selecting

# %% [markdown]
# *explain purpose of indexing and slicing here...explain what a value is and what an index is...maybe use a series with an index as an example*

# %%
import pandas as pd

surveys_df=pd.read_csv("../../data/biology/surveys.csv")

# %% [markdown]
# ## Basics

# %% [markdown]
# we have the most basic indexing using []

# %% [markdown]
# can select a column by name

# %%
surveys['species']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-60952d022b53> in <module>()
# ----> 1 surveys['species']
#
# NameError: name 'surveys' is not defined

# %% [markdown]
# you can also set a variable to your subset

# %%
surveys_species=surveys['species']

# %% [markdown]
# You can pass a list of columns to [] to select columns in that order. If a column is not contained in the dataframe, an exception will be raised. This is useful for applying a function (like transform) to a subset of your columns.

# %%
surveys[['species', 'plot']]

# %% [markdown]
# You can also access columns on DataFrames as an attribute:

# %%
surveys.wgt

# %% [markdown]
# ## Slicing Ranges

# %% [markdown]
# Slicing using the [] operator slices rows in dataframes. When slicing in pandas the start bound and the stop bound are included. data[start:stop]

# %%
surveys[0:3]

# %%
surveys[:5]

# %%
surveys[-1:]

# %% [markdown]
# can set values using slices

# %%
surveys_copy=surveys.copy()
surveys_copy[0:3]=0

# %% [markdown]
# ## Selection with .ix method

# %% [markdown]
# Return the column in question and its data type. Format is [row, column] *add in what inputs are, etc*

# %%
surveys.ix[:,'species']

# %% [markdown]
# you can also set variables to your subset of data. this will be a series

# %%
surveys_species=surveys.ix[:,'species']

# %% [markdown]
# more slicing

# %%
surveys.ix[100,['species', 'wgt']]

# %% [markdown]
# ## Selection by Label

# %% [markdown]
# all labels must be in index or a KeyError will be raised. remember that the start bound and the stop bound are included. Integers can be used, but they refer to the index label and not the position.

# %%
surveys.loc[[0,10],:]

# %%
surveys.loc[0,['species', 'plot','wgt']]

# %% [markdown]
# ## Selection by Position

# %% [markdown]
# 0-based indexing, start bounds included and upper bound excluded. trying to use a non-integer will raise an IndexError

# %%
surveys.iloc[:3]

# %% [markdown]
# integer slicing

# %%
surveys.iloc[0:10, 4:6]

# %% [markdown]
# slicing rows

# %%
surveys.iloc[0:3,:]

# %% [markdown]
# slicing columns

# %%
surveys.iloc[:, 0:5]

# %% [markdown]
# integer lists

# %%
surveys.iloc[[2,4,6],[1,3,5]]

# %% [markdown]
# can pull out a specific data point

# %%
surveys_df.iloc[7,156]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-a541cc2abbf4> in <module>()
# ----> 1 surveys_df.iloc[7,156]
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.pyc in __getitem__(self, key)
#    1140     def __getitem__(self, key):
#    1141         if type(key) is tuple:
# -> 1142             return self._getitem_tuple(key)
#    1143         else:
#    1144             return self._getitem_axis(key, axis=0)
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.pyc in _getitem_tuple(self, tup)
#    1345     def _getitem_tuple(self, tup):
#    1346
# -> 1347         self._has_valid_tuple(tup)
#    1348         try:
#    1349             return self._getitem_lowerdim(tup)
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.pyc in _has_valid_tuple(self, key)
#     128             if i >= self.obj.ndim:
#     129                 raise IndexingError('Too many indexers')
# --> 130             if not self._has_valid_type(k, i):
#     131                 raise ValueError("Location based indexing can only have [%s] "
#     132                                  "types" % self._valid_types)
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.pyc in _has_valid_type(self, key, axis)
#    1314             return True
#    1315         elif com.is_integer(key):
# -> 1316             return self._is_valid_integer(key, axis)
#    1317         elif (_is_list_like(key)):
#    1318             return self._is_valid_list_like(key, axis)
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.pyc in _is_valid_integer(self, key, axis)
#    1327         ax = self.obj._get_axis(axis)
#    1328         if key > len(ax):
# -> 1329             raise IndexError("single positional indexer is out-of-bounds")
#    1330         return True
#    1331
#
# IndexError: single positional indexer is out-of-bounds

# %%
surveys_df[surveys_df.year==1999]=0

# %%
surveys_df[surveys_df.year==0]
# Out:
#        record_id  month  day  year  plot species sex  wgt
# 29023          0      0    0     0     0       0   0    0
# 29024          0      0    0     0     0       0   0    0
# 29025          0      0    0     0     0       0   0    0
# 29026          0      0    0     0     0       0   0    0
# 29027          0      0    0     0     0       0   0    0
# 29028          0      0    0     0     0       0   0    0
# 29029          0      0    0     0     0       0   0    0
# 29030          0      0    0     0     0       0   0    0
# 29031          0      0    0     0     0       0   0    0
# 29032          0      0    0     0     0       0   0    0
# 29033          0      0    0     0     0       0   0    0
# 29034          0      0    0     0     0       0   0    0
# 29035          0      0    0     0     0       0   0    0
# 29036          0      0    0     0     0       0   0    0
# 29037          0      0    0     0     0       0   0    0
# 29038          0      0    0     0     0       0   0    0
# 29039          0      0    0     0     0       0   0    0
# 29040          0      0    0     0     0       0   0    0
# 29041          0      0    0     0     0       0   0    0
# 29042          0      0    0     0     0       0   0    0
# 29043          0      0    0     0     0       0   0    0
# 29044          0      0    0     0     0       0   0    0
# 29045          0      0    0     0     0       0   0    0
# 29046          0      0    0     0     0       0   0    0
# 29047          0      0    0     0     0       0   0    0
# 29048          0      0    0     0     0       0   0    0
# 29049          0      0    0     0     0       0   0    0
# 29050          0      0    0     0     0       0   0    0
# 29051          0      0    0     0     0       0   0    0
# 29052          0      0    0     0     0       0   0    0
# ...          ...    ...  ...   ...   ...     ...  ..  ...
# 30128          0      0    0     0     0       0   0    0
# 30129          0      0    0     0     0       0   0    0
# 30130          0      0    0     0     0       0   0    0
# 30131          0      0    0     0     0       0   0    0
# 30132          0      0    0     0     0       0   0    0
# 30133          0      0    0     0     0       0   0    0
# 30134          0      0    0     0     0       0   0    0
# 30135          0      0    0     0     0       0   0    0
# 30136          0      0    0     0     0       0   0    0
# 30137          0      0    0     0     0       0   0    0
# 30138          0      0    0     0     0       0   0    0
# 30139          0      0    0     0     0       0   0    0
# 30140          0      0    0     0     0       0   0    0
# 30141          0      0    0     0     0       0   0    0
# 30142          0      0    0     0     0       0   0    0
# 30143          0      0    0     0     0       0   0    0
# 30144          0      0    0     0     0       0   0    0
# 30145          0      0    0     0     0       0   0    0
# 30146          0      0    0     0     0       0   0    0
# 30147          0      0    0     0     0       0   0    0
# 30148          0      0    0     0     0       0   0    0
# 30149          0      0    0     0     0       0   0    0
# 30150          0      0    0     0     0       0   0    0
# 30151          0      0    0     0     0       0   0    0
# 30152          0      0    0     0     0       0   0    0
# 30153          0      0    0     0     0       0   0    0
# 30154          0      0    0     0     0       0   0    0
# 30155          0      0    0     0     0       0   0    0
# 30156          0      0    0     0     0       0   0    0
# 30157          0      0    0     0     0       0   0    0
#
# [1135 rows x 8 columns]

# %%
surveys_df.loc[1:4]
# Out:
#    record_id  month  day  year  plot species sex  wgt
# 1          2      7   16  1977     3      NL   M  NaN
# 2          3      7   16  1977     2      DM   F  NaN
# 3          4      7   16  1977     7      DM   M  NaN
# 4          5      7   16  1977     3      DM   M  NaN

# %%
surveys_df[(surveys_df.year>=1980) & (surveys_df.wgt<=8)]
# Out:
#        record_id  month  day  year  plot species sex  wgt
# 2276        2277      1   15  1980     8      PF   M    8
# 2312        2313      1   15  1980    21      PF   M    8
# 2379        2380      1   16  1980    15      PF   M    7
# 2392        2393      1   16  1980     3      PF   F    7
# 2403        2404      1   16  1980     4      PF   F    7
# 2404        2405      1   16  1980    15      PF   F    7
# 2413        2414      2   24  1980    11      PF   F    7
# 2431        2432      2   24  1980    21      RM   F    8
# 2502        2503      2   25  1980     3      PF   M    7
# 2505        2506      2   25  1980     3      PF   F    5
# 2508        2509      2   25  1980    13      RM   M    8
# 2513        2514      2   25  1980     4      PF   F    7
# 2515        2516      2   25  1980    15      PF   M    7
# 2528        2529      2   25  1980    15      RM   M    8
# 2532        2533      2   25  1980     3      PF   M    8
# 2535        2536      3    9  1980     2      PF   F    7
# 2539        2540      3    9  1980    21      PF   M    7
# 2547        2548      3    9  1980     3      PF   F    6
# 2575        2576      3    9  1980    15      PF   F    7
# 2582        2583      3    9  1980     3      PF   M    8
# 2590        2591      3    9  1980     4      PF   M    5
# 2594        2595      3    9  1980     3      PF   M    8
# 2616        2617      3    9  1980    11      PF   F    7
# 2635        2636      3    9  1980     3      PF   M    7
# 2638        2639      3    9  1980    21      RM   M    8
# 2719        2720      3    9  1980     5      PF   M    6
# 2728        2729      3    9  1980     4      PF   F    7
# 2729        2730      3    9  1980     6      PF   M    7
# 2752        2753      3   21  1980     1      PF   F    7
# 2753        2754      3   21  1980    21      RM   F    5
# ...          ...    ...  ...   ...   ...     ...  ..  ...
# 32925      32926     10   14  2001     4      PF   F    8
# 33122      33123     11   18  2001     3      PF   M    7
# 33291      33292     12   15  2001    23      RM   F    8
# 33297      33298     12   15  2001    20      RM   F    8
# 33396      33397      2    9  2002     1      RO   M    8
# 33404      33405      2    9  2002     2      RM   M    8
# 33428      33429      2    9  2002     3      PF   M    8
# 33534      33535      2   10  2002    13      PF   F    7
# 33550      33551      2   10  2002    15      RM   F    7
# 33560      33561      2   10  2002    10      RM   F    8
# 33564      33565      2   10  2002    10      RO   F    8
# 33646      33647      3   14  2002     3      PF   M    8
# 33653      33654      3   14  2002     4      PF   M    8
# 33656      33657      3   14  2002     4      PF   F    8
# 33716      33717      3   14  2002    13      PF   M    7
# 33729      33730      3   14  2002    15      RM   F    7
# 33868      33869      4   17  2002     4      PF   F    8
# 33869      33870      4   17  2002     4      PF   M    7
# 34070      34071      5   16  2002     4      PF   M    7
# 34279      34280      6   15  2002    23      RM   M    7
# 34312      34313      6   16  2002     6      PP   M    8
# 34402      34403      6   16  2002    16      PF   F    5
# 34527      34528      7   13  2002    24      RM   M    7
# 34557      34558      7   14  2002     4      PF   F    7
# 34662      34663      7   14  2002    16      RM   M    7
# 35100      35101     11   10  2002     9      PF   M    7
# 35171      35172     11   10  2002    14      PF   F    7
# 35300      35301     12    8  2002     4      PF   M    6
# 35307      35308     12    8  2002     6      PF   F    6
# 35505      35506     12   31  2002     6      PF   M    8
#
# [1400 rows x 8 columns]

# %%
pd.unique(surveys_df.sex)
# Out:
# array(['M', 'F', nan, 'R', 'P', 'Z', 0], dtype=object)

# %%
#[(surveys_df.sex == ['P', 'Z'])]
surveys_df[(surveys_df.sex == 'P')]
# Out:
#        record_id  month  day  year  plot species sex  wgt
# 22487      22488      7   21  1995     8      PP   P   13

# %%
surveys_df[surveys_df['sex'].isin(['P', 'Z'])]
# Out:
#        record_id  month  day  year  plot species sex  wgt
# 22487      22488      7   21  1995     8      PP   P   13
# 23838      23839      4   15  1996     3      PP   Z   18

# %%
isnan(surveys_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-8783c1f76b6a> in <module>()
# ----> 1 isnan(surveys_df)
#
# NameError: name 'isnan' is not defined

# %%
import numpy as np
np.isnan(surveys_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-1da4825c4b4e> in <module>()
#       1 import numpy as np
# ----> 2 np.isnan(surveys_df)
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
surveys_df[pd.isnull(surveys_df) ]
# Out:
#        record_id  month  day  year  plot species  sex  wgt
# 0            NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 1            NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 2            NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 3            NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 4            NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 5            NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 6            NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 7            NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 8            NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 9            NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 10           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 11           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 12           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 13           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 14           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 15           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 16           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 17           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 18           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 19           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 20           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 21           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 22           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 23           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 24           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 25           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 26           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 27           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 28           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 29           NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# ...          ...    ...  ...   ...   ...     ...  ...  ...
# 35519        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35520        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35521        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35522        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35523        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35524        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35525        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35526        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35527        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35528        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35529        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35530        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35531        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35532        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35533        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35534        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35535        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35536        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35537        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35538        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35539        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35540        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35541        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35542        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35543        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35544        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35545        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35546        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35547        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
# 35548        NaN    NaN  NaN   NaN   NaN     NaN  NaN  NaN
#
# [35549 rows x 8 columns]
